# %% [markdown]
# # Springboard Capstone 3-Data Wrangling and EDA

# %% [raw]
# The problem of image classification goes like this: Given a set of images that are all labeled with a single category, we’re asked to predict these categories for a novel set of test images and measure the accuracy of the predictions. There are a variety of challenges associated with this task, including viewpoint variation, scale variation, intra-class variation, image deformation, image occlusion, illumination conditions, and background clutter.
# How might we go about writing an algorithm that can classify images into distinct categories? Computer Vision researchers have come up with a data-driven approach to solve this. Instead of trying to specify what every one of the image categories of interest look like directly in code, they provide the computer with many examples of each image class and then develop learning algorithms that look at these examples and learn about the visual appearance of each class.
#
# In other words, they first accumulate a training dataset of labeled images, then feed it to the computer to process the data. Given that fact, the complete image classification pipeline can be formalized as follows:
#
# Our input is a training dataset that consists of N images, each labeled with one of K different classes.
#
# Then, we use this training set to train a classifier to learn what every one of the classes looks like.
#
# In the end, we evaluate the quality of the classifier by asking it to predict labels for a new set of images that it’s never seen before.
#
# We’ll then compare the true labels of these images to the ones predicted by the classifier.

# %% [markdown]
# # Image Processing: Image Classification and Recognition System

# %% [markdown]
# Image processing is used for everything from automatically tagging pictures in social media to unlocking our phones. Recent advancements in deep learning have made the accuracy of face recognition better. In this project, I will like to use the Humans dataset to develop a face recognition system that can detect faces in images, identify the faces, and modify faces with digital makeup. I will start by setting up a development environment, and then train machine learning models to analyze images and identify facial landmarks. I will also code the facial feature detection, representing a face as a set of measurements, and encoding faces. Lastly, I will repurpose and adjust any of the existing ML systems I built.
#
# The dataset was taken from Kaggle(https://www.kaggle.com/ashwingupta3012/human-faces?select=Humans). It has a collection of 7.2k+ images. It has a mix of front face, side profile pictures which will help achieve great identifying results and an improved range of classifier/recognition possibilities.

# %% [markdown]
# # Deliverables

# %% [raw]
# Detecting faces in images.
# Analyzing a histogram of oriented gradients (HOG)
# Identifying faces in images.
# Locating facial features in images.
# Coding for face detection.
# Finding lookalikes using face detection.
# Generating face encoding automatically.
# Use of OpenCV: leverage the image-processing power of OpenCV using methods like template matching and machine learning data to identify and recognize features.

# %%
import os, random, shutil, glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from skimage import color
from skimage import io, filters, transform, restoration, measure, segmentation, feature
# %matplotlib inline
from PIL import Image
import glob
import skimage

# %% [markdown]
# There are two folders with images. one is named train, that's where all the training images are stored. Humans_faces folder has about 1000 images that the model will be tested upon.

# %% [raw]
# Select an image randomly from the human faces folder

# %%
folder = '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file'
#a=random.choice(os.listdir(folder))
#print(a)
filename = '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/train'

# %%
images = [os.path.join(root, filename)
          for root, dirs, files in os.walk(folder)
          for filename in files
          if filename.lower().endswith('.png')]

ic = []
for img in images:
    ic.append(io.imread(img).flatten())

# %%
ic
plt.show(ic)

# %%
skimage.io.imshow_collection(ic, plugin=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-319-0779e9fcba71> in <module>
# ----> 1 skimage.io.imshow_collection(ic, plugin=None)
#
# /Applications/anaconda3/envs/springboard/lib/python3.8/site-packages/skimage/io/_io.py in imshow_collection(ic, plugin, **plugin_args)
#     177
#     178     """
# --> 179     return call_plugin('imshow_collection', ic, plugin=plugin, **plugin_args)
#     180
#     181
#
# /Applications/anaconda3/envs/springboard/lib/python3.8/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /Applications/anaconda3/envs/springboard/lib/python3.8/site-packages/skimage/io/_plugins/matplotlib_plugin.py in imshow_collection(ic, *args, **kwargs)
#     196     ax = np.asarray(axes).ravel()
#     197     for n, image in enumerate(ic):
# --> 198         ax[n].imshow(image, *args, **kwargs)
#     199     kwargs['ax'] = axes
#     200     return fig
#
# /Applications/anaconda3/envs/springboard/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Applications/anaconda3/envs/springboard/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# /Applications/anaconda3/envs/springboard/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     709         if not (self._A.ndim == 2
#     710                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 711             raise TypeError("Invalid shape {} for image data"
#     712                             .format(self._A.shape))
#     713
#
# TypeError: Invalid shape (904332,) for image data

# %% [markdown]
# Create a list of images in the train folder that are in jpg format

# %%
train_dir_jpg = [] # empty list to put all the jpg format images
for filename in glob.glob('train/*.jpg'): #assuming jpg
    im=Image.open(filename)
    train_dir_jpg.append(im)

# %%
train_dir_jpg
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x650 at 0x141CB4F10>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1066x1600 at 0x143359A30>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x141CB4B80>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1151 at 0x142334910>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x750 at 0x1421B4100>]

# %% [markdown]
# Create a list of images in the train folder that are in jpeg format

# %%
train_dir_jpeg = []
for filename in glob.glob('train/*.jpeg'):
    im=Image.open(filename)
    train_dir_jpeg.append(im)

# %%
train_dir_jpeg
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1066x1600 at 0x144EC5A60>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1066x1600 at 0x144EC5D30>]

# %% [markdown]
# Create a list of images in the train folder that are in png format

# %%
train_dir_png = []
for filename in glob.glob('train/*.png'):
    im=Image.open(filename)
    train_dir_png.append(im)

# %%
train_dir_png
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080 at 0x144EC5D60>]

# %% [markdown]
# While it is great to have seperate variables for image format, it will be better to have a list of filenames of all images in the train folder.

# %%
def get_imagelist(path): #define get_imagelist function to get the list of all images in a folder
  """  Returns a list of filenames for
    all jpg images in a directory. """

  return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpeg')] #.jpeg means only get images in jpeg format

# %%
get_imagelist('/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces')
# Out:
# ['/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (10).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (11).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (12).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (13).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (14).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (15).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (16).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (17).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (18).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (19).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (2).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (20).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (22).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (23).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (24).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (25).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (26).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (27).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (28).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (29).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (3).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (30).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (31).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (32).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (33).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (34).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (35).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (36).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (37).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (38).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (39).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (4).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (40).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (41).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (42).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (43).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (44).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (45).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (46).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (47).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (48).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (49).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (5).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (50).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (51).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (52).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (53).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (54).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (55).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (56).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (57).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (58).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (59).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (6).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (60).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (61).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (62).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (63).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (64).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (65).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (66).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (67).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (68).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (69).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (70).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (71).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (72).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (73).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (74).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (75).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (76).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (77).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (78).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (79).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (8).jpeg',
#  '/Users/goldenrule/Desktop/Machine_Learning/Cap_3_file/Humans_faces/1 (9).jpeg']

# %% [markdown]
# # Lets see what some of the training images look like

# %%
skimage.io.imread_collection(folder, conserve_memory=True, plugin=None)

# %%
png_train = skimage.io.imshow_collection(train_dir_png, plugin=None)

# %% [markdown]
# Above is the only file on png format in the train folder

# %%
jpg_train = skimage.io.imshow_collection(train_dir_jpg, plugin=None)

# %% [markdown]
# There are only 5 files on jpg format

# %%
jpeg_train = skimage.io.imshow_collection(train_dir_jpeg, plugin=None)

# %% [markdown]
# 2 files on jpeg format

# %%
train_afr_m = io.imread('train/train_bk_m.jpg', as_gray=False)
plt.imshow(train_afr_m)

# %%
img = plt.imread('train/train_bk_m.jpg')
plt.imshow(img)

# %%
train_wt_m = io.imread('train/train_wt_m.jpg', as_gray=False)
show_image(train_wt_m)

# %%
def show_image(image, title='Image', cmap_type='gray'):
    plt.figure(figsize=(16, 12))
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()
def plot_comparison(original, filtered, title_filtered):
    fig, (ax1, ax2) = \
        plt.subplots(ncols=2, figsize=(16, 12), sharex=True, sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(title_filtered)
    ax2.axis('off')

# %%
grape = io.imread('train/train_wt_f.png', as_gray=True)

# %% [markdown]
# # Plotting Images, Points, and Lines

# %%
from pylab import *

# read image to array
im = array(Image.open('train/train_wt_m.jpg'))

# plot the image
imshow(im)

# some points
x = [100,100,400,400]
y = [200,500,200,500]

# plot the points with red star-markers
plot(x,y,'r*')

# line plot connecting the first two points
plot(x[:2],y[:2])

# add title and show the plot
title('Plotting: "train/train_wt_m.jpg"')
show()

# %% [markdown]
# # Histograms
